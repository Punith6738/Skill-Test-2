# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("/content/MNSO.csv")

# %%
df.head()
# Out:
#          Date       Open       High        Low      Close  Adj Close    Volume
# 0  2020-10-15  24.400000  24.900000  20.650000  20.879999  20.129318  21708500
# 1  2020-10-16  22.010000  24.490000  21.780001  23.180000  22.346630   7596000
# 2  2020-10-19  23.760000  23.889999  20.650000  20.879999  20.129318   4074200
# 3  2020-10-20  21.600000  22.120001  19.459999  20.000000  19.280958   2263600
# 4  2020-10-21  20.299999  22.500000  20.280001  21.049999  20.293205   2718100

# %%
df.tail()
# Out:
#            Date       Open       High        Low      Close  Adj Close  \
# 712  2023-08-16  20.500000  20.500000  19.750000  19.889999  19.889999
# 713  2023-08-17  20.600000  20.945000  20.355000  20.410000  20.410000
# 714  2023-08-18  19.799999  20.290001  19.129999  20.150000  20.150000
# 715  2023-08-21  20.150000  20.635000  19.930000  20.360001  20.360001
# 716  2023-08-22  22.100000  22.459999  21.209999  22.350000  22.350000
#
#       Volume
# 712   868200
# 713   912300
# 714   757700
# 715  1224000
# 716  2959700

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 717 entries, 0 to 716
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       717 non-null    object
#  1   Open       717 non-null    float64
#  2   High       717 non-null    float64
#  3   Low        717 non-null    float64
#  4   Close      717 non-null    float64
#  5   Adj Close  717 non-null    float64
#  6   Volume     717 non-null    int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 39.3+ KB

# %%
df.nunique()
# Out:
# Date         717
# Open         613
# High         625
# Low          614
# Close        608
# Adj Close    642
# Volume       702
# dtype: int64

# %%
df.isnull()
# Out:
#       Date   Open   High    Low  Close  Adj Close  Volume
# 0    False  False  False  False  False      False   False
# 1    False  False  False  False  False      False   False
# 2    False  False  False  False  False      False   False
# 3    False  False  False  False  False      False   False
# 4    False  False  False  False  False      False   False
# ..     ...    ...    ...    ...    ...        ...     ...
# 712  False  False  False  False  False      False   False
# 713  False  False  False  False  False      False   False
# 714  False  False  False  False  False      False   False
# 715  False  False  False  False  False      False   False
# 716  False  False  False  False  False      False   False
#
# [717 rows x 7 columns]

# %%
df.isnull().sum()
# Out:
# Date         0
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %%
(df.isnull().sum()/(len(df)))*100
# Out:
# Date         0.0
# Open         0.0
# High         0.0
# Low          0.0
# Close        0.0
# Adj Close    0.0
# Volume       0.0
# dtype: float64

# %%
df=df.drop(["Volume"],axis=1)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 717 entries, 0 to 716
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       717 non-null    object
#  1   Open       717 non-null    float64
#  2   High       717 non-null    float64
#  3   Low        717 non-null    float64
#  4   Close      717 non-null    float64
#  5   Adj Close  717 non-null    float64
# dtypes: float64(5), object(1)
# memory usage: 33.7+ KB

# %%
df.describe()
# Out:
#              Open        High         Low       Close   Adj Close
# count  717.000000  717.000000  717.000000  717.000000  717.000000
# mean    15.242541   15.678982   14.765137   15.220962   14.882941
# std      7.134960    7.326443    6.881738    7.112518    6.847605
# min      4.510000    4.700000    4.450000    4.500000    4.500000
# 25%      9.030000    9.380000    8.810000    9.030000    8.808436
# 50%     15.730000   16.120001   15.340000   15.740000   15.461099
# 75%     20.049999   20.440001   19.360001   20.030001   19.377361
# max     34.639999   35.209999   33.160000   34.770000   33.519943

# %%
print(df.High.unique())
print(df.Close.nunique())
# Out:
# [24.9      24.49     23.889999 22.120001 22.5      21.299999 20.299999
#  19.27     19.049999 19.690001 19.309999 19.155001 20.65     21.200001
#  20.790001 20.67     24.790001 22.74     21.43     21.       20.629999
#  20.695    20.325001 20.18     19.889999 19.73     19.347    18.42
#  20.440001 20.34     20.544001 19.99     20.200001 22.08     22.1
#  21.75     21.833    23.190001 23.110001 23.35     23.33     23.99
#  24.4      24.690001 28.799    28.5      30.24     31.6      29.66
#  27.254999 27.4      27.379999 26.700001 26.879999 29.25     29.5
#  28.645    29.309999 31.209999 31.43     31.110001 29.35     30.98
#  32.66     31.950001 30.620001 34.990002 33.75     29.75     31.66
#  32.32     32.349998 31.315001 31.389999 31.49     30.709999 35.189999
#  35.209999 33.259998 34.139999 34.639999 34.380001 32.5      32.700001
#  31.129999 30.299999 29.815001 31.       27.940001 28.200001 28.66
#  29.700001 29.540001 28.129999 26.5      25.450001 25.325001 25.030001
# ...

# %%
import pandas as pd
import numpy as np
data=pd.read_csv("/content/MNSO.csv")
data={'A':[1,2,np.NaN,3,4],
     'B':[np.NaN,2,3,4,np.NaN],
    'C':[1,2,3,np.NaN,np.NaN]
     }
df=pd.DataFrame(data)
print(df)
# Out:
#      A    B    C
# 0  1.0  NaN  1.0
# 1  2.0  2.0  2.0
# 2  NaN  3.0  3.0
# 3  3.0  4.0  NaN
# 4  4.0  NaN  NaN

# %%
df1=df.dropna()
print(df1)
# Out:
#      A    B    C
# 1  2.0  2.0  2.0

# %%
df2=df.dropna(axis=1)
print(df2)
# Out:
# Empty DataFrame
# Columns: []
# Index: [0, 1, 2, 3, 4]

# %%
df3=df.fillna(df.mean())
print(df3)
# Out:
#      A    B    C
# 0  1.0  3.0  1.0
# 1  2.0  2.0  2.0
# 2  2.5  3.0  3.0
# 3  3.0  4.0  2.0
# 4  4.0  3.0  2.0

# %%
import pandas as pd

data = pd.Series([24.400000, 22.010000, 22.010000, 23.760000, 20.299999])
upper_cap = 24.400000
lower_cap = 20.299999

data_clipped = data.clip(lower=lower_cap, upper=upper_cap)
print("Data with capped outliers:", data_clipped)
# Out:
# Data with capped outliers: 0    24.400000
# 1    22.010000
# 2    22.010000
# 3    23.760000
# 4    20.299999
# dtype: float64
